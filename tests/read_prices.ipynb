# %%
from cadCAD.configuration import Configuration
from cadCAD.engine import ExecutionContext, ExecutionMode, Executor
from cadCAD.configuration.utils import config_sim
from cadCAD.configuration import append_configs
from cadCAD import configs
import pandas as pd
import numpy as np
from numpy.random import rand
import matplotlib.pyplot as plt

from os import path
import sys
sys.path.append(path.abspath("../dai_cadcad"))

from state import *
from policies import *
from sim_configs import *

# %%
partial_state_update_blocks = [{
    "policies": {
        "read_dai_price": read_dai_price_usd,
    },
    "variables": {
        "dai_price_usd": update_dai_price_usd,
    }
}]

# %%
append_configs(sim_configs=read_dai_price_sim_config,
               initial_state=initial_state,
               partial_state_update_blocks=partial_state_update_blocks,
               policy_ops=[policy_reduce]
               )

# %%
exec_mode = ExecutionMode()
exec_context = ExecutionContext(context=exec_mode.single_mode)
executor = Executor(exec_context=exec_context, configs=configs)

raw_result, tensor, sessions = executor.execute()
result = pd.DataFrame(raw_result)
# Out:
#                   ___________    ____
#   ________ __ ___/ / ____/   |  / __ \
#  / ___/ __` / __  / /   / /| | / / / /
# / /__/ /_/ / /_/ / /___/ ___ |/ /_/ /
# \___/\__,_/\__,_/\____/_/  |_/_____/
# by cadCAD
#
# Execution Mode: single_proc
# Configuration Count: 2
# Dimensions of the first simulation: (Timesteps, Params, Runs, Vars) = (2, 14, 1, 9)
# Execution Method: parallelize_simulations
# Execution Mode: parallelized
# FalseFalse
#
# TrueTrue
#
# Total execution time: 0.39s

# %%
result
# Out:
#                                                  vat  \
# 0  {'dummy_vault': {'vault_id': '', 'eth': 0, 'da...
# 1  {'dummy_vault': {'vault_id': '', 'eth': 0, 'da...
# 2  {'dummy_vault': {'vault_id': '', 'eth': 0, 'da...
# 3  {'dummy_vault': {'vault_id': '', 'eth': 0, 'da...
# 4  {'dummy_vault': {'vault_id': '', 'eth': 0, 'da...
# 5  {'dummy_vault': {'vault_id': '', 'eth': 0, 'da...
#
#                                  vow  \
# 0  {'debt_dai': 0, 'surplus_dai': 0}
# 1  {'debt_dai': 0, 'surplus_dai': 0}
# 2  {'debt_dai': 0, 'surplus_dai': 0}
# 3  {'debt_dai': 0, 'surplus_dai': 0}
# 4  {'debt_dai': 0, 'surplus_dai': 0}
# 5  {'debt_dai': 0, 'surplus_dai': 0}
#
#                                              flipper  \
# 0  {'dummy_flip': {'flip_id': '', 'phase': '', 'd...
# 1  {'dummy_flip': {'flip_id': '', 'phase': '', 'd...
# 2  {'dummy_flip': {'flip_id': '', 'phase': '', 'd...
# 3  {'dummy_flip': {'flip_id': '', 'phase': '', 'd...
# ...

# %%
result["dai_price_usd"]
# Out:
# 0    0.000000
# 1    0.000000
# 2    1.000577
# 3    0.000000
# 4    0.000000
# 5    1.000577
# Name: dai_price_usd, dtype: float64
