# %%
from cadCAD.configuration import Configuration
from cadCAD.engine import ExecutionContext, ExecutionMode, Executor
from cadCAD.configuration.utils import config_sim
from cadCAD.configuration import append_configs
from cadCAD import configs
import pandas as pd
import numpy as np
from numpy.random import rand
import matplotlib.pyplot as plt

from os import path
import sys
sys.path.append(path.abspath("../dai_cadcad"))

from state import *
from policies import *
from sim_configs import *

# %%
partial_state_update_blocks = [{
    "policies": {
        "read_dai_price": read_dai_price_usd,
        "join_vaults": join_vault_all,
        "exit_vaults": exit_vault_all
    },
    "variables": {
        "dai_price_usd": update_dai_price_usd,
        "vat": update_vat,
        "eth_ilk": update_eth_ilk
    }
}]

# %%
append_configs(sim_configs=vault_join_exit_sim_config,
               initial_state=initial_state,
               partial_state_update_blocks=partial_state_update_blocks,
               policy_ops=[policy_reduce]
               )

# %%
exec_mode = ExecutionMode()
exec_context = ExecutionContext(context=exec_mode.single_mode)
executor = Executor(exec_context=exec_context, configs=configs)

raw_result, tensor, sessions = executor.execute()
result = pd.DataFrame(raw_result)
# Out:
#                   ___________    ____
#   ________ __ ___/ / ____/   |  / __ \
#  / ___/ __` / __  / /   / /| | / / / /
# / /__/ /_/ / /_/ / /___/ ___ |/ /_/ /
# \___/\__,_/\__,_/\____/_/  |_/_____/
# by cadCAD
#
# Execution Mode: single_proc
# Configuration Count: 2
# Dimensions of the first simulation: (Timesteps, Params, Runs, Vars) = (100, 14, 1, 9)
# Execution Method: parallelize_simulations
# Execution Mode: parallelized
# Above peg (1.000577)Above peg (1.000577)
#
# Below peg (0.999932)Below peg (0.999932)
#
# Above peg (1.000175)Above peg (1.000175)
#
# Above peg (1.000164)Above peg (1.000164)
#
# Above peg (1.000962)
# Above peg (1.000962)
# Above peg (1.001)
# Above peg (1.001)
# Above peg (1.000999)
# Above peg (1.000999)
# Above peg (1.000223)
# Above peg (1.000223)
# Above peg (1.000238)
# Above peg (1.000238)
# Below peg (0.999931)
# Below peg (0.999931)
# Below peg (0.999472)
# Below peg (0.999472)
# Above peg (1.000538)
# Above peg (1.000538)
# Above peg (1.001)
# Above peg (1.001)
# Above peg (1.001331)
# Above peg (1.000638)Above peg (1.001331)
#
# Above peg (1.000079)
# Above peg (1.000638)
# Above peg (1.000137)
# Above peg (1.000079)
# Above peg (1.000202)
# Above peg (1.000137)
# Above peg (1.000209)
# Above peg (1.000202)
# Above peg (1.000234)
# Above peg (1.000209)
# Above peg (1.000966)
# Above peg (1.000234)
# Above peg (1.000383)
# Above peg (1.000966)
# Above peg (1.000204)
# Above peg (1.000383)
# Above peg (1.001327)
# Above peg (1.000204)
# Above peg (1.001)
# Above peg (1.001327)
# Above peg (1.001194)
# Above peg (1.001088)
# Above peg (1.001)
# Above peg (1.001099)
# Above peg (1.001194)
# Above peg (1.001)
# Above peg (1.001088)
# Above peg (1.001)
# Above peg (1.001099)
# Above peg (1.001001)
# Above peg (1.001)
# Above peg (1.001001)
# Above peg (1.001)
# Above peg (1.001002)
# Above peg (1.001001)
# Above peg (1.001001)
# Above peg (1.001001)
# Above peg (1.001)
# Above peg (1.001002)
# Above peg (1.001)
